# %% [markdown]
# # ARIMA and SARIMAX:

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined in the requirements.in file
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import warnings
warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')

#importing day-wise data of cities
df= pd.read_csv('../data/city_day.csv')

df['Date'] = pd.to_datetime(df['Date'])

#visualizing the top rows of the dataset
df.tail(5)
# Out:
#                 City       Date  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Visakhapatnam 2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam 2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam 2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam 2020-06-30  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam 2020-07-01  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 29526  0.47   8.55  23.30     2.24    12.07    0.73  41.0          Good
# 29527  0.52  12.72  30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528  0.48   8.42  30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529  0.52   9.84  28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530  0.59   2.10  17.05      NaN      NaN     NaN  50.0          Good

# %% [markdown]
# We pivot the values from the 'City' column, so that we can have a comparitive view of the value of every city's AQI through every day.
#
# Then we resample them to find the mean of every month, so now our dataset contains month-wise data.

# %%
cities_all = df.pivot_table(values='AQI', index=['Date'], columns='City')
cities_all=cities_all.add_suffix('_AQI')
cities=cities_all.resample(rule='MS').mean()
cities.head()
# Out:
# City        Ahmedabad_AQI  Aizawl_AQI  Amaravati_AQI  Amritsar_AQI  \
# Date
# 2015-01-01     350.333333         NaN            NaN           NaN
# 2015-02-01     520.640000         NaN            NaN           NaN
# 2015-03-01     418.571429         NaN            NaN           NaN
# 2015-04-01     308.640000         NaN            NaN           NaN
# 2015-05-01     263.466667         NaN            NaN           NaN
#
# City        Bengaluru_AQI  Bhopal_AQI  Brajrajnagar_AQI  Chandigarh_AQI  \
# Date
# 2015-01-01            NaN         NaN               NaN             NaN
# 2015-02-01            NaN         NaN               NaN             NaN
# 2015-03-01     130.545455         NaN               NaN             NaN
# 2015-04-01     113.733333         NaN               NaN             NaN
# 2015-05-01     102.774194         NaN               NaN             NaN
#
# City        Chennai_AQI  Coimbatore_AQI  ...  Jorapokhar_AQI  Kochi_AQI  \
# Date                                     ...
# 2015-01-01          NaN             NaN  ...             NaN        NaN
# 2015-02-01          NaN             NaN  ...             NaN        NaN
# 2015-03-01   363.800000             NaN  ...             NaN        NaN
# 2015-04-01   175.862069             NaN  ...             NaN        NaN
# 2015-05-01   176.129032             NaN  ...             NaN        NaN
#
# City        Kolkata_AQI  Lucknow_AQI  Mumbai_AQI  Patna_AQI  Shillong_AQI  \
# Date
# 2015-01-01          NaN          NaN         NaN        NaN           NaN
# 2015-02-01          NaN          NaN         NaN        NaN           NaN
# 2015-03-01          NaN   264.272727         NaN        NaN           NaN
# 2015-04-01          NaN   118.586207         NaN        NaN           NaN
# 2015-05-01          NaN   137.000000         NaN        NaN           NaN
#
# City        Talcher_AQI  Thiruvananthapuram_AQI  Visakhapatnam_AQI
# Date
# 2015-01-01          NaN                     NaN                NaN
# 2015-02-01          NaN                     NaN                NaN
# 2015-03-01          NaN                     NaN                NaN
# 2015-04-01          NaN                     NaN                NaN
# 2015-05-01          NaN                     NaN                NaN
#
# [5 rows x 26 columns]
